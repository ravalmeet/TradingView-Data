# %%
from TradingviewData import TradingViewData,Interval

request = TradingViewData()

# %%
request.search('METAL','MCX')
# Out:
# [{'symbol': 'MCXMETLDEX',
#   'description': 'MCX ICOMDEX BASE METAL',
#   'type': 'index',
#   'exchange': 'MCX',
#   'currency_code': 'INR',
#   'provider_id': 'ice',
#   'country': 'IN'},
#  {'symbol': 'MCXMETLDEX',
#   'description': 'MCX ICOMDEX BASE METAL FUTURES',
#   'type': 'futures',
#   'exchange': 'MCX',
#   'currency_code': 'INR',
#   'provider_id': 'ice',
#   'country': 'IN',
#   'contracts': [{'symbol': 'MCXMETLDEX1!',
#     'typespecs': ['continuous', 'synthetic'],
#     'description': 'CONTINUOUS: CURRENT CONTRACT IN FRONT'},
#    {'symbol': 'MCXMETLDEX2!',
#     'typespecs': ['continuous', 'synthetic'],
#     'description': 'CONTINUOUS: NEXT CONTRACT IN FRONT'},
#    {'symbol': 'MCXMETLDEXG2023', 'description': 'FEB 2023'},
#    {'symbol': 'MCXMETLDEXH2023', 'description': 'MAR 2023'},
#    {'symbol': 'MCXMETLDEXJ2023', 'description': 'APR 2023'}]}]

# %%
nifty_data = request.get_hist(symbol='NIFTY',exchange='NSE',interval=Interval.hour_1,n_bars=1000)

nifty_data
# Out:
#                         symbol      open      high       low     close  \
# datetime
# 2022-07-15 12:15:00  NSE:NIFTY  15949.45  15983.05  15927.30  15979.50
# 2022-07-15 13:15:00  NSE:NIFTY  15980.05  15992.25  15945.10  15992.25
# 2022-07-15 14:15:00  NSE:NIFTY  15993.65  16054.30  15987.90  16053.25
# 2022-07-15 15:15:00  NSE:NIFTY  16052.90  16066.95  16044.10  16052.85
# 2022-07-18 09:15:00  NSE:NIFTY  16152.30  16199.70  16142.20  16184.80
# ...                        ...       ...       ...       ...       ...
# 2023-02-10 11:15:00  NSE:NIFTY  17866.60  17876.95  17820.35  17823.75
# 2023-02-10 12:15:00  NSE:NIFTY  17824.15  17842.95  17815.90  17822.70
# 2023-02-10 13:15:00  NSE:NIFTY  17822.85  17859.25  17815.10  17850.55
# 2023-02-10 14:15:00  NSE:NIFTY  17850.10  17865.15  17823.65  17861.80
# 2023-02-10 15:15:00  NSE:NIFTY  17862.10  17864.40  17840.00  17843.35
#
#                          volume
# datetime
# 2022-07-15 12:15:00  21558646.0
# 2022-07-15 13:15:00  25357416.0
# 2022-07-15 14:15:00  39190692.0
# 2022-07-15 15:15:00  19423958.0
# 2022-07-18 09:15:00  53958590.0
# ...                         ...
# 2023-02-10 11:15:00  21562199.0
# 2023-02-10 12:15:00  24809266.0
# 2023-02-10 13:15:00  38897505.0
# 2023-02-10 14:15:00  38252608.0
# 2023-02-10 15:15:00  17747095.0
#
# [1000 rows x 6 columns]

# %%
nifty_futures = request.get_hist(symbol='NIFTY',exchange='NSE',interval=Interval.hour_1,n_bars=1000,fut_contract=1)

nifty_futures
# Out:
#                           symbol      open      high       low     close  \
# datetime
# 2022-07-15 12:15:00  NSE:NIFTY1!  15959.35  15995.00  15930.30  15987.70
# 2022-07-15 13:15:00  NSE:NIFTY1!  15987.10  16009.60  15955.00  16009.15
# 2022-07-15 14:15:00  NSE:NIFTY1!  16008.45  16070.00  16000.00  16068.90
# 2022-07-15 15:15:00  NSE:NIFTY1!  16069.55  16083.90  16062.10  16074.00
# 2022-07-18 09:15:00  NSE:NIFTY1!  16199.00  16520.00  16170.45  16207.00
# ...                          ...       ...       ...       ...       ...
# 2023-02-10 11:15:00  NSE:NIFTY1!  17892.00  17899.90  17845.00  17848.65
# 2023-02-10 12:15:00  NSE:NIFTY1!  17849.35  17872.75  17847.00  17850.65
# 2023-02-10 13:15:00  NSE:NIFTY1!  17851.35  17884.00  17844.70  17877.00
# 2023-02-10 14:15:00  NSE:NIFTY1!  17877.40  17888.00  17849.30  17886.00
# 2023-02-10 15:15:00  NSE:NIFTY1!  17886.00  17887.00  17869.00  17870.00
#
#                         volume
# datetime
# 2022-07-15 12:15:00  1003100.0
# 2022-07-15 13:15:00   821700.0
# 2022-07-15 14:15:00  2255300.0
# 2022-07-15 15:15:00  1096150.0
# 2022-07-18 09:15:00  2582300.0
# ...                        ...
# 2023-02-10 11:15:00  1115850.0
# 2023-02-10 12:15:00   369950.0
# 2023-02-10 13:15:00   486700.0
# 2023-02-10 14:15:00   819950.0
# 2023-02-10 15:15:00   368700.0
#
# [1000 rows x 6 columns]

# %%
relience_data = request.get_hist(symbol='RELIANCE',exchange='NSE',interval=Interval.min_5,n_bars=5000)

relience_data
# Out:
#                            symbol     open     high      low    close  \
# datetime
# 2022-11-09 11:20:00  NSE:RELIANCE  2607.90  2607.95  2605.60  2606.65
# 2022-11-09 11:25:00  NSE:RELIANCE  2606.20  2606.85  2604.85  2605.95
# 2022-11-09 11:30:00  NSE:RELIANCE  2605.75  2607.00  2603.95  2606.45
# 2022-11-09 11:35:00  NSE:RELIANCE  2606.00  2607.85  2605.05  2607.50
# 2022-11-09 11:40:00  NSE:RELIANCE  2607.50  2610.00  2606.35  2609.50
# ...                           ...      ...      ...      ...      ...
# 2023-02-10 15:05:00  NSE:RELIANCE  2336.70  2337.35  2335.00  2336.00
# 2023-02-10 15:10:00  NSE:RELIANCE  2336.40  2337.00  2335.45  2336.50
# 2023-02-10 15:15:00  NSE:RELIANCE  2336.50  2338.00  2335.30  2336.20
# 2023-02-10 15:20:00  NSE:RELIANCE  2336.75  2337.70  2335.00  2337.35
# 2023-02-10 15:25:00  NSE:RELIANCE  2337.35  2337.65  2336.00  2336.90
#
#                        volume
# datetime
# 2022-11-09 11:20:00   22114.0
# 2022-11-09 11:25:00   25276.0
# 2022-11-09 11:30:00   31536.0
# 2022-11-09 11:35:00   27541.0
# 2022-11-09 11:40:00   25894.0
# ...                       ...
# 2023-02-10 15:05:00   67412.0
# 2023-02-10 15:10:00   94976.0
# 2023-02-10 15:15:00  134330.0
# 2023-02-10 15:20:00  109691.0
# 2023-02-10 15:25:00   68028.0
#
# [5000 rows x 6 columns]

# %%
crudeoil_data = request.get_hist(symbol='MCXMETLDEX',exchange='MCX',interval=Interval.hour_1,n_bars=5000)

crudeoil_data
# Out:
# ERROR:TradingviewData.main:The read operation timed out
# ERROR:TradingviewData.main:no data, please check the exchange and symbol

# %%
nifty_data.close.plot(figsize=(15,10),use_index=False)
# Out:
# <AxesSubplot:>
